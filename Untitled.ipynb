# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style("darkgrid")

import warnings
warnings.filterwarnings("ignore")

# %%
game_df = pd.read_csv('/home/mishal/Documents/datasets/vgsales.csv')
print(game_df.shape)
game_df[:7]
# Out:
# (16598, 11)
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                    Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7     New Super Mario Bros.       DS  2006.0      Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# ...

# %%
game_df.columns.to_list()
# Out:
# ['Rank',
#  'Name',
#  'Platform',
#  'Year',
#  'Genre',
#  'Publisher',
#  'NA_Sales',
#  'EU_Sales',
#  'JP_Sales',
#  'Other_Sales',
#  'Global_Sales']

# %%
racing_df = game_df[game_df['Genre']=='Racing']
#in the above for getting the values of genre which are racing "filtering the data"
racing_df
# Out:
#         Rank                                               Name Platform  \
# 2          3                                     Mario Kart Wii      Wii
# 11        12                                      Mario Kart DS       DS
# 28        29                             Gran Turismo 3: A-Spec      PS2
# 42        43                                       Mario Kart 7      3DS
# 47        48                                     Gran Turismo 4      PS2
# ...      ...                                                ...      ...
# 16530  16533                           Sébastien Loeb Rally Evo     XOne
# 16543  16546                             Driving Simulator 2011       PC
# 16573  16576                                Mini Desktop Racing      Wii
# 16574  16577  Yattaman Wii: BikkuriDokkiri Machine de Mou Ra...      Wii
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
#
#          Year   Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %%
#racing_df['Year'].isnull().sum()

# %%
racing_data = racing_df[['Year','NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']]
racing_data = racing_data.set_index('Year', drop=True)
racing_data
# Out:
#         NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Year
# 2008.0     15.85     12.88      3.79         3.31         35.82
# 2005.0      9.81      7.57      4.13         1.92         23.42
# 2001.0      6.85      5.09      1.87         1.16         14.98
# 2011.0      4.74      3.91      2.67         0.89         12.21
# 2004.0      3.01      0.01      1.10         7.53         11.66
# ...          ...       ...       ...          ...           ...
# 2016.0      0.00      0.01      0.00         0.00          0.01
# 2011.0      0.00      0.01      0.00         0.00          0.01
# 2007.0      0.01      0.00      0.00         0.00          0.01
# 2008.0      0.00      0.00      0.01         0.00          0.01
# 2008.0      0.00      0.00      0.00         0.00          0.01
#
# [1249 rows x 5 columns]

# %%
game_data = game_df
plt.plot(game_data.groupby('Year')['Global_Sales'].mean(), label='Gloabl Sales')
plt.plot(racing_data.groupby('Year')['Global_Sales'].mean(), label='Racing Gloabl Sales')
plt.legend()
plt.title('Sales History')
plt.show()

# %%
racing_ds = racing_data[['NA_Sales','EU_Sales', 'Global_Sales']].sort_index()
racing_ds
# Out:
#         NA_Sales  EU_Sales  Global_Sales
# Year
# 1981.0      0.45      0.03          0.48
# 1982.0      0.37      0.02          0.39
# 1982.0      1.10      0.07          1.18
# 1984.0      0.00      0.00          1.52
# 1984.0      0.26      0.01          0.27
# ...          ...       ...           ...
# NaN         0.02      0.00          0.02
# NaN         0.00      0.00          0.02
# NaN         0.00      0.01          0.02
# NaN         0.00      0.01          0.01
# NaN         0.01      0.00          0.01
#
# [1249 rows x 3 columns]

# %%
from sklearn.linear_model import BayesianRidge, LinearRegression
from sklearn.model_selection import train_test_split
#train_test_split(x,y, test_size=0.2)
model =  LinearRegression()

# %%
game_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
game_data = game_data.copy()

le = LabelEncoder()
feature = ["Platform", "Genre"]


for col in feature:
    game_data[col] = le.fit_transform(game_data[col])

# %%
X = game_df[['Platform', 'Genre', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].values

y = game_df['Global_Sales'].values
X 
#x.drop(columns='year')
X[:5], y[:5]
# Out:
# (array([['Wii', 'Sports', 41.49, 29.02, 3.77, 8.46],
#         ['NES', 'Platform', 29.08, 3.58, 6.81, 0.77],
#         ['Wii', 'Racing', 15.85, 12.88, 3.79, 3.31],
#         ['Wii', 'Sports', 15.75, 11.01, 3.28, 2.96],
#         ['GB', 'Role-Playing', 11.27, 8.89, 10.22, 1.0]], dtype=object),
#  array([82.74, 40.24, 35.82, 33.  , 31.37]))

# %%
from sklearn.preprocessing import LabelEncoder

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=45)
from sklearn.metrics import r2_score

# %%
model = LinearRegression()
from sklearn.metrics import accuracy_score 

model.fit(X_train, y_train)

predictions = model.predict(X_test)
score = accuracy_score(y_test,predictions)



#r2_MultiLinear = r2_score(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_21371/2172932505.py in <module>
#       2 from sklearn.metrics import accuracy_score
#       3
# ----> 4 model.fit(X_train, y_train)
#       5
#       6 predictions = model.predict(X_test)
#
# ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~/.local/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# ...
